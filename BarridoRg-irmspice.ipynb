# %%
import ltspice
import numpy as np
import matplotlib.pyplot as plt
import csv
import os as os

# %%
x = [10, 15, 18, 22, 27, 33, 47, 100]
y = [186.39*1e-3, 154.1*1e-3, 141.3*1e-3, 128.35*1e-3, 116.31*1e-3, 105.53*1e-3, 88.77*1e-3, 59.268*1e-3]
Vrms = 10.6
y = [item * Vrms for item in y]

# %%
plt.plot(x, y, marker="o")
plt.xlabel("$R_{g}$ $[\Omega]$")
plt.ylabel("Potencia [W]")
plt.xticks(x, fontsize = 9)
plt.yticks(y)
plt.show()
